# %%
import tensorflow as tf
import tensorflow.keras
import matplotlib.pyplot as plt
import numpy as np
from tensorflow.keras.datasets import cifar10

# %%
(X_train,y_train),(X_test,y_test) = cifar10.load_data()
# Out:
# ...
# 170498071/170498071 [==============================] - 2s 0us/step

# %%
X_train.shape
# Out:
# (50000, 32, 32, 3)

# %%
plt.rcParams['figure.figsize'] = (10,10) # Make the figures a bit biggerfor i in range(9):
for i in range(9):
  plt.subplot(3,3,i+1)
  plt.imshow(X_test[i], cmap='gray', interpolation='none')
  plt.title("Class {}".format(y_test[i]))

# %%
from keras.utils import to_categorical

nb_classes = 10
y_train = to_categorical(y_train,nb_classes)

y_test = to_categorical(y_test,nb_classes)

# %%
y_train.shape
# Out:
# (50000, 10)

# %%
X_train = X_train/255
X_test = X_test/255

# %%
model=tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(32,32,3)),
    tf.keras.layers.Dense(256,activation=tf.nn.relu),
    tf.keras.layers.Dense(128,activation=tf.nn.relu),
    tf.keras.layers.Dense(64,activation=tf.nn.relu),
    tf.keras.layers.Dense(10,activation=tf.nn.softmax),

])

# %%
model.compile(loss="categorical_crossentropy",optimizer="adam",metrics=["accuracy"])

# %%
history=model.fit(X_train,y_train,batch_size=128,verbose=1,epochs=10,validation_data=(X_test,y_test))
# Out:
# Epoch 1/10
# 391/391 [==============================] - 13s 28ms/step - loss: 1.9044 - accuracy: 0.3100 - val_loss: 1.7746 - val_accuracy: 0.3693
# Epoch 2/10
# 391/391 [==============================] - 13s 33ms/step - loss: 1.6978 - accuracy: 0.3931 - val_loss: 1.6729 - val_accuracy: 0.4054
# Epoch 3/10
# 391/391 [==============================] - 8s 21ms/step - loss: 1.6218 - accuracy: 0.4225 - val_loss: 1.5909 - val_accuracy: 0.4367
# Epoch 4/10
# 391/391 [==============================] - 11s 28ms/step - loss: 1.5623 - accuracy: 0.4409 - val_loss: 1.5555 - val_accuracy: 0.4446
# Epoch 5/10
# 391/391 [==============================] - 10s 24ms/step - loss: 1.5146 - accuracy: 0.4590 - val_loss: 1.4959 - val_accuracy: 0.4635
# Epoch 6/10
# 391/391 [==============================] - 9s 23ms/step - loss: 1.4810 - accuracy: 0.4720 - val_loss: 1.5421 - val_accuracy: 0.4559
# Epoch 7/10
# ...

# %%
X_train.shape
# Out:
# (50000, 32, 32, 3)

# %%
from keras.layers import Conv2D,MaxPooling2D, Flatten, Dropout,Dense

# %%
model1=tf.keras.Sequential([
    tf.keras.layers.Conv2D(32,(3,3),activation="relu",input_shape=(32,32,3)),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(32,(3,3),activation="relu"),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(128,activation=tf.nn.relu),
    tf.keras.layers.Dense(64,activation=tf.nn.relu),
    tf.keras.layers.Dense(10,activation=tf.nn.softmax),

])

# %%
model1.compile(loss="categorical_crossentropy",optimizer="adam",metrics=["accuracy"])

# %%
history1=model.fit(X_train,y_train,batch_size=128,verbose=1,epochs=10,validation_data=(X_test,y_test))
# Out:
# Epoch 1/10
# 391/391 [==============================] - 9s 22ms/step - loss: 1.3605 - accuracy: 0.5144 - val_loss: 1.4253 - val_accuracy: 0.4926
# Epoch 2/10
# 391/391 [==============================] - 10s 25ms/step - loss: 1.3371 - accuracy: 0.5247 - val_loss: 1.4452 - val_accuracy: 0.4886
# Epoch 3/10
# 391/391 [==============================] - 7s 18ms/step - loss: 1.3240 - accuracy: 0.5280 - val_loss: 1.4551 - val_accuracy: 0.4800
# Epoch 4/10
# 391/391 [==============================] - 8s 21ms/step - loss: 1.3043 - accuracy: 0.5339 - val_loss: 1.4069 - val_accuracy: 0.5074
# Epoch 5/10
# 391/391 [==============================] - 8s 22ms/step - loss: 1.2946 - accuracy: 0.5390 - val_loss: 1.4036 - val_accuracy: 0.5071
# Epoch 6/10
# 391/391 [==============================] - 7s 19ms/step - loss: 1.2726 - accuracy: 0.5470 - val_loss: 1.4220 - val_accuracy: 0.4974
# Epoch 7/10
# ...
